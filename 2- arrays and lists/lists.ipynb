# %% [markdown]
# ## Lists

# %% [markdown]
# #### 1D operations

# %% [markdown]
# creation

# %%
numbers = [10, 20, 30, 40, 50]
fruits = ['apple', 'banana', 'cherry']
mixed_list = [7, 3.14, 'abc', True, None]

# %%
type(mixed_list)
# Out:
# list

# %% [markdown]
# access

# %%
numbers[2]
# Out:
# 30

# %%
fruits[1]
# Out:
# 'banana'

# %% [markdown]
# traversal

# %%
for fruit in fruits: 
    print(fruit, end = " ")
# Out:
# apple banana cherry

# %% [markdown]
# insertion

# %% [markdown]
# append

# %%
numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers.append(60)

# %%
numbers
# Out:
# [10, 20, 30, 40, 50, 60]

# %% [markdown]
# insert

# %%
numbers.insert(3, 35)

# %%
numbers
# Out:
# [10, 20, 30, 35, 25, 40, 50, 60]

# %% [markdown]
# merging

# %% [markdown]
# extend

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits = ['orange', 'grape']

# %%
fruits.extend(more_fruits)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'grape']

# %%
some_more_fruits = ['kiwi', 'melon']
fruits.extend(some_more_fruits)
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'grape', 'kiwi', 'melon']

# %% [markdown]
# concatenation

# %%
li1 = [1, 2, 3]
li2 = [4, 5]

li1 + li2
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# deletion

# %%
li = [3, 4, 6, 4, 3, 1, 2, 5]
print(li)

li.remove(6)
print(li)
# Out:
# [3, 4, 6, 4, 3, 1, 2, 5]
# [3, 4, 4, 3, 1, 2, 5]

# %% [markdown]
# pop

# %%
numbers
# Out:
# [10, 20, 30, 35, 25, 40, 50, 60]

# %%
numbers.pop()
# Out:
# 60

# %%
numbers
# Out:
# [10, 20, 30, 35, 25, 40, 50]

# %%
numbers.pop(2)
# Out:
# 30

# %%
numbers
# Out:
# [10, 20, 35, 25, 40, 50]

# %% [markdown]
# del

# %%
del numbers[2]

# %%
numbers
# Out:
# [10, 20, 25, 40, 50]

# %%
li
# Out:
# [3, 4, 4, 3, 1, 2, 5]

# %%
li.clear()

# %%
li
# Out:
# []

# %%
type(li)
# Out:
# list

# %% [markdown]
# updation

# %%
mixed_list
# Out:
# [7, 3.14, 'abc', True, None]

# %%
mixed_list[1] = 6.626
print(mixed_list)
# Out:
# [7, 6.626, 'abc', True, None]

# %% [markdown]
# count

# %%
li = [2, 3, 4, 2, 2, 5, 3]
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.count(2)
# Out:
# 3

# %%
li.sort()

# %%
li
# Out:
# [2, 2, 2, 3, 3, 4, 5]

# %%
li1 = [2, 5, 3, 1, -4, 5]
sorted(li1)
# Out:
# [-4, 1, 2, 3, 5, 5]

# %% [markdown]
# reverse

# %%
li1 = [3, 4, 1, 2, -5, 7, 4]
li1
# Out:
# [3, 4, 1, 2, -5, 7, 4]

# %%
li1.reverse()

# %%
li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %% [markdown]
# copy

# %%
li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li2 = li1.copy()
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li1.remove(4)

# %%
li1
# Out:
# [7, -5, 2, 1, 4, 3]

# %%
li1.pop()
# Out:
# 3

# %%
li1
# Out:
# [7, -5, 2, 1, 4]

# %%
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %% [markdown]
# split

# %%
numbers
# Out:
# [10, 20, 25, 40, 50]

# %%
numbers[:2]
# Out:
# [10, 20]

# %%
numbers[1:]
# Out:
# [20, 25, 40, 50]

# %% [markdown]
# ## 2D Operations

# %% [markdown]
# creation

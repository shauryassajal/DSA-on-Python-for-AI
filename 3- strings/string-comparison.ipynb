# %% [markdown]
# ### String Comparison

# %% [markdown]
# #### Lexicographically

# %%
str1 = 'banana'
str2 = 'banned'

# %%
ord('a'), ord('n')
# Out:
# (97, 110)

# %%
str2 < str1
# Out:
# True

# %%
str3 = 'ball'
str4 = 'balls'

str3 < str4
# Out:
# True

# %%
'apple' == 'apple'
# Out:
# True

# %% [markdown]
# #### Case-sensitivity

# %%
str1 = 'zoo'
str2 ='zoO'

# %%
str1 == str2
# Out:
# False

# %%
for ch1, ch2 in zip(str1, str2):
    print(ch1, ord(ch1), '-', ch2, ord(ch2))
# Out:
# b 98 - b 98
# a 97 - a 97
# n 110 - n 110
# a 97 - n 110
# n 110 - e 101
# a 97 - d 100

# %%
str1 > str2
# Out:
# False

# %% [markdown]
# #### Sorting

# %%
str1 = 'abcABC'
str1
# Out:
# 'abcABC'

# %%
for ch in str1:
    print(ch, ord(ch))
# Out:
# a 97
# b 98
# c 99
# A 65
# B 66
# C 67

# %%
sorted(str1)
# Out:
# ['A', 'B', 'C', 'a', 'b', 'c']

# %% [markdown]
# ### 1. Built in data types and data structures

# %% [markdown]
# #### 1.1 Numeric Types

# %%
a = 10
type(a)
# Out:
# int

# %%
a = 24.
type(a)
# Out:
# float

# %%
a = 5 + 3j
type(a)
# Out:
# complex

# %% [markdown]
# #### 1.2 Sequence Types

# %%
a = 'Hey there guys! This is actually a string.'
type(a)
# Out:
# str

# %%
b = "This is a string too"
type(b)
# Out:
# str

# %%
c = '''But now this is 
a very long string, but atlast, 
this is also a string.'''

type(c)
# Out:
# str

# %%
li = [1,2,3,4, 4.5,'abc', 2+5j]
type(li)
# Out:
# list

# %%
t = (1, 2, 3)
type(t)
# Out:
# tuple

# %%
t1 = 5, 6, 7
type(t1)
# Out:
# tuple

# %%
z = (6.5)
type(z)
# Out:
# float

# %%
z = 6.5, 
type(z)
# Out:
# tuple

# %%
r = range(5)
type(r)
# Out:
# range

# %%
r = range(5)
print(list(r))
# Out:
# [0, 1, 2, 3, 4]

# %%
r
# Out:
# range(0, 5)

# %% [markdown]
# #### 1.3 Set types

# %%
s1 = {2, 3, 4}
type(s1)
# Out:
# set

# %%
s2 = {2, 3, 4, 5, 5 , 5, 6, 6, 6, 7}
s2
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
s3 = frozenset({1, 2})
type(s3)
# Out:
# frozenset

# %% [markdown]
# #### 1.4 Mapping types

# %%
d = {
    'name': 'Shaurya',
    'age': 19,
    'occupation': 'GenAI Engineer'
}

type(d)
# Out:
# dict

# %% [markdown]
# #### 1.5 Boolean Types

# %%
a = True
type(a)
# Out:
# bool

# %%
a = False
type(a)
# Out:
# bool

# %% [markdown]
# #### 1.6 None Type

# %%
a = None
type(a)
# Out:
# NoneType

# %% [markdown]
# ### 2. Control Structurs

# %% [markdown]
# #### 2.1 if-else

# %%
a = -1

if a > 5:
    print("Greater than 5")
else: 
    print("Not greater than 5")
# Out:
# Not greater than 5

# %%
a = 6

if a % 2 == 0: 
    print("Even")
else: 
    print("odd")
# Out:
# Even

# %% [markdown]
# ### 2.2 if-elif-else

# %%
marks = 98

if marks > 90: 
    print('Exceptional')
elif marks > 70: 
    print('Very good')
elif marks > 50: 
    print('Good')
else: 
    print('Bad')
# Out:
# Exceptional

# %% [markdown]
# ### 3. Loops

# %% [markdown]
# #### 3.1 For loop

# %%
li = [1, 2, 3, 4, 9, 18]

print(li[0])
print(li[1])
print(li[2])
print(li[3])
print(li[4])
print(li[5])
# Out:
# 1
# 2
# 3
# 4
# 9
# 18

# %%
for element in li:
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 9
# 18

# %%
for element in range(20, 31): 
    if element % 2 == 0: 
        print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %%
for element in range(20, 31, 2):
    print(element)
# Out:
# 20
# 22
# 24
# 26
# 28
# 30

# %% [markdown]
# #### 3.2 While Loop

# %%
a = 1 

while a <= 5:
    print(a)
    a += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## 4. Functions

# %% [markdown]
# #### 4.1 Defination/Call

# %%
def random_func():
    print("This is a random function created by me")

# %%
random_func()
# Out:
# This is a random function created by me

# %%
def add_numbers():
    a = 2+3
    print(a)

# %%
add_numbers()
# Out:
# 5

# %% [markdown]
# #### 4.2 Input to Functions

# %%
def add_two_numbers(a, b):
    print(f"Sum of {a} and {b} is {a+b}")

# %%
add_two_numbers(5, 7)
# Out:
# Sum of 5 and 7 is 12

# %%
def greeting(name):
    print(f'Hi {name}, good morning!')

# %%
greeting('Shaurya')
# Out:
# Hi Shaurya, good morning!

# %% [markdown]
# #### 4.3 Output from fucntions

# %%
def add_two_numbers(a, b):
    print(f"Sum of {a} and {b} is {a+b}")

# %%
c = add_two_numbers(5, 7)
# Out:
# Sum of 5 and 7 is 12

# %%
print(c)
# Out:
# None

# %%
def add_two_numbers(a, b):
    res = a + b
    print(f"Sum of {a} and {b} is {res}")
    return res

# %%
c = add_two_numbers(5, 7)
# Out:
# Sum of 5 and 7 is 12

# %%
print(c)
# Out:
# 12

# %%
def greeting(name):
    return f"Hi {name}, good morning!"

# %%
greeting('Shaurya')
# Out:
# 'Hi Shaurya, good morning!'

# %%
c = greeting('Sajal')

# %%
print(c)
# Out:
# Hi Sajal, good morning!

# %% [markdown]
# ## 5. Built-in Functions

# %%
li = [5, 6 , 24, 4, 8 , 12]

# %% [markdown]
# #### 5.1 min

# %%
min(li)
# Out:
# 4

# %%
min((3,-4, 4,6, 7 ))
# Out:
# -4

# %%
min(['shekhar', 'aaron', 'shaurya', 'sajal'])
# Out:
# 'aaron'

# %% [markdown]
# #### 5.2 Max

# %%
max(li)
# Out:
# 24

# %%
max((3, 4, -4, -2, 6, 0))
# Out:
# 6

# %%
max(['sharya', 'neelam', 'ben', 'jack'])
# Out:
# 'sharya'

# %% [markdown]
# #### 5.3 SUM

# %%
sum(li)
# Out:
# 59

# %%
sum((3, 4, -4, -2, 6, 0))
# Out:
# 7

# %% [markdown]
# #### 5.4 len

# %%
len(li)
# Out:
# 6

# %%
len(['aaron', 'shaurya', 'sajal', 'jack'])
# Out:
# 4

# %%
li
# Out:
# [5, 6, 24, 4, 8, 12]

# %%
sum(li) / len(li)
# Out:
# 9.833333333333334

# %% [markdown]
# #### 5.5 sorted

# %%
li
# Out:
# [5, 6, 24, 4, 8, 12]

# %%
sorted_li = sorted(li)
sorted_li
# Out:
# [4, 5, 6, 8, 12, 24]

# %%
type(sorted_li)
# Out:
# list

# %%
li
# Out:
# [5, 6, 24, 4, 8, 12]

# %%
sorted((6, 4, -1, -3, 0, 45, 21))
# Out:
# [-3, -1, 0, 4, 6, 21, 45]

# %% [markdown]
# #### 5.6 Enumerate

# %%
names = ['shekhar', 'aaron', 'shaurya', 'sajal']

# %%
list(range(len(names)))
# Out:
# [0, 1, 2, 3]

# %%
for i in range(len(names)):
    print(i, names[i])
# Out:
# 0 shekhar
# 1 aaron
# 2 shaurya
# 3 sajal

# %%
for i, name in enumerate(names):
    print(i, name)
# Out:
# 0 shekhar
# 1 aaron
# 2 shaurya
# 3 sajal

# %%
for i, name in enumerate(names, start=1):
    print(i, name)
# Out:
# 1 shekhar
# 2 aaron
# 3 shaurya
# 4 sajal

# %% [markdown]
# #### 5.7 Zip

# %%
names
# Out:
# ['shekhar', 'aaron', 'shaurya', 'sajal']

# %%
colors = ['red', 'green', 'blue', 'yellow']
ages = [23, 45, 12, 67]

# %%
for name, age, color in zip(names, ages, colors):
    print(f'{name} is {age} years old and likes {color} color.')
# Out:
# shekhar is 23 years old and likes red color.
# aaron is 45 years old and likes green color.
# shaurya is 12 years old and likes blue color.
# sajal is 67 years old and likes yellow color.

# %% [markdown]
# #### 6. List Comprehensions

# %%
result = []

for i in range(1, 11):
    if i % 2 == 0:
        result.append(i)

result
# Out:
# [2, 4, 6, 8, 10]

# %%
list(range(2, 11, 2))
# Out:
# [2, 4, 6, 8, 10]

# %%
ages
# Out:
# [23, 45, 12, 67]

# %%
for age in ages: 
    if age > 30:
        print('Greater than 30')
    else:
        print('Less than 30')
# Out:
# Less than 30
# Greater than 30
# Less than 30
# Greater than 30

# %%
['Greater than 30' if age > 30 else 'Less than 30' for age in ages]
# Out:
# ['Less than 30', 'Greater than 30', 'Less than 30', 'Greater than 30']

# %% [markdown]
# #### 7. Classes

# %%
class MyRectangle:
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
        self.random_attribute = 0
        self.another_random_attribute = 'abc'
    
    def get_perimeter(self):
        return 2 * (self.length + self.breadth)
    
    def get_area(self):
        return self.length * self.breadth
    
    def get_length(self):
        return self.length
    
    def get_breadth(self):
        return self.breadth

# %%
obj1 = MyRectangle(length=5, breadth=3)

# %%
obj2 = MyRectangle(length=10, breadth=4)

# %%
obj1

# %%
obj1.breadth
# Out:
# 3

# %%
obj1.random_attribute
# Out:
# 0

# %%
obj1.another_random_attribute
# Out:
# 'abc'

# %%
obj1.get_length()
# Out:
# 5

# %%
MyRectangle.get_length(obj1)
# Out:
# 5

# %%
MyRectangle.get_length(obj2)
# Out:
# 10

# %%
obj1.get_area()
# Out:
# 15

# %%
obj2.get_area()
# Out:
# 40
